# %%
import tiktoken
from BasicLM_MPS import ModelWrapper as MPS_LM
from BasicLM_MLX import ModelWrapper as MLX_LM

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class CharTokenizer():
    def __init__(self, intext: str):
        self.charset = set(intext)
        sorted_charset = sorted(list(self.charset))
        self.stoi = {c:i for i,c in enumerate(sorted_charset)}
        self.itos = {i:c for i,c in enumerate(sorted_charset)}
        self.n_vocab = len(self.charset)
    
    def encode(self, s: str) -> list[int]:
        return [self.stoi[c] for c in s]
    
    def decode(self, l: list[int]) -> str:
        return ''.join(self.itos[i] for i in l)

# %%
config = {
        'batch_size': 32,
        'block_size': 256,
        'embedding_dim': 384,
        'max_iters': 5000,
        'learning_rate': 3e-4,
        'eval_interval': 500,
        'eval_iters': 200,
        'num_heads': 4,
        'num_layers': 6,
        'split_ratio': 0.9,
}

with open("input.txt", 'r', encoding="utf-8") as f:
    text = f.read()

config['tokenizer'] = CharTokenizer(text)
# config['tokenizer'] = tiktoken.get_encoding("r50k_base")

# %%
mpsLM = MPS_LM(config, text)
# Out:
# 10.761665 M parameters

# %%
mpsLM.train()
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 0: train loss 99.3934, val loss 98.9136
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 500: train loss 3.3190, val loss 3.3536
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 1000: train loss 3.3143, val loss 3.3539
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 1500: train loss 3.2833, val loss 3.3199
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 2000: train loss 2.3974, val loss 2.4197
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 2500: train loss 1.9933, val loss 2.1120
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 3000: train loss 1.7551, val loss 1.9292
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 3500: train loss 1.6051, val loss 1.8504
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 4000: train loss 1.5221, val loss 1.7788
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 4500: train loss 1.4444, val loss 1.7319
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# Estimating loss:   0%|          | 0/200 [00:00<?, ?it/s]
# step 4999: train loss 1.4045, val loss 1.7417

# %%
mpsLM.generate_text(2000)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# At so madam, beter grip,
# Myself my life, not the king, I eed,
# To my crock; none the wanger of you, and drums:
# To keep purger me wit be his of hand
# To bout first: not revenge favours-my lord;
# One if as my good withou from the prespermit's
# Hath knock of the king, but selft swiets
# To there dogard, by when they pars in true;
# Show there horse; but as some to Lord to
# For Warwick, erre means determine,
# Where it which you met strength'd witch'd not
# The more extrencts.
#
# BRAKENBY:
# Fearth, thy must teets witre friething to terve
# of thy lap throck provoke what A' the prosest
# Whom angelen'd: I wit; procied you, thou shalt.
#
# DUKE OF YORK:
# How't thou, on I would repath: for your wear give you:
# Here here's were you?
#
# WARWICK:
# Here's so the wallk what illo thee cloman?
#
# KING RICHARD I:
# Thou did kind Henry's lies Lord:
# And what my Gremio?
#
# DUKE OF AUMERLE:
# Provost:
# Theself friend, are self your mother;
# Ay, affer of the first cheek, I'll gard,
# Where father forbear take her feel heaven,
# you therefore well the have merry body.
#
# DUKE OF YORK:
# Yendery, tell your lord; our as notisff,
# Where's were were were more traitor's dream,
# Then how burn'd a worst needs the greatirery;
# Shall he should we well welcoure it,
# Where is not to ire the friends' me
# the storoye; every lord, let them here mighty,
# Shillisy leople your the hath till as a perperived:
# He meet now yet of were a foe's very wedil,
# The trial as were he crown'd fly day,
# Then to Elbows. There wrettched Sorrow'?
# Romeo! sate; yet makne, my lord, every Ludry's for Lawick a
# drop the king erter: Romeo. All is there reques,
# To fitie the her credature for the farewell:
# I the tell respected,
# Profelnt it, what not wasoment you are--lear
# Redeemptioney, my leave your can extile,
# For for your freent not be, whom short crown,
# Bestricke by! there is were wark against to gend,
# Come ambost, your her.
#
# MENENIUS:
# Volse, sir; you piteous of Exward's love.
#
# FROTH:
# Will?
#
# PERCAN:
# O Rivers!
#
# ROMEO:
# Welcome you!
# Telll, fear reend and the of termion.
#
# First Ser

# %%
mlxLM = MLX_LM(config, text)
# Out:
# 10.76 M parameters

# %%
mlxLM.train()
# Out:
#   0%|          | 1/5000 [00:11<16:01:36, 11.54s/it]
# step 0: train 5.9001, val 5.9038
#  10%|█         | 501/5000 [01:12<2:16:21,  1.82s/it]
# step 500: train 3.1944, val 3.2388
#  20%|██        | 1001/5000 [02:14<3:57:12,  3.56s/it]
# step 1000: train 1.7746, val 1.9119
#  30%|███       | 1501/5000 [03:16<3:32:16,  3.64s/it]
# step 1500: train 1.4227, val 1.6425
#  40%|████      | 2001/5000 [04:19<3:02:47,  3.66s/it]
# step 2000: train 1.3027, val 1.5756
#  50%|█████     | 2501/5000 [05:22<2:32:00,  3.65s/it]
# step 2500: train 1.2090, val 1.5476
#  60%|██████    | 3001/5000 [06:24<2:01:02,  3.63s/it]
# step 3000: train 1.1408, val 1.5575
#  70%|███████   | 3501/5000 [07:26<1:08:44,  2.75s/it]
# step 3500: train 1.0707, val 1.6095
#  80%|████████  | 4001/5000 [08:28<59:12,  3.56s/it]
# step 4000: train 0.9902, val 1.6731
#  90%|█████████ | 4501/5000 [09:30<29:58,  3.60s/it]
# step 4500: train 0.9055, val 1.7324
# 100%|██████████| 5000/5000 [10:32<00:00,  7.90it/s]
# step 4999: train 0.8179, val 1.8622

# %%
mlxLM.generate_text()
# Out:
# 100%|██████████| 2000/2000 [00:06<00:00, 288.86it/s]
# KING LEY VI:
# Yes, that has my fault was loog on him;
# And then, Varren, for as too sudden hold,
# To catcle fill'd with words with paalever,
# And made extemporalt inveoI, as strange to see
# Camillo you and follies, then I am against
# Your present could not, sufer gold, will I
# like mine own.
#
# GREMIO:
# O letWery neighber.
#
# PAULINA:
# Too deep tradesper! be gone, let believe no law,
# Preserved us yet pleased and cheerp of man,
# Makes not this to be content with some others,
# That I heard you shall follow what you have.
# What, will you please me for a horse. Havk!
#
# ROMEO:
# Park, not a pity thief; charge goes have that we tent
# Thou and thirst assees him.
#
# MERCUTIO:
# O how he him!
#
# MERCUTIO:
# O cursed witch!
# We hope
# I had given is honour.
#
# BENVOLIO:
# Go you to love, take your lady's extrement
# Upon my father promise of the happy:
# My birth Warwick's death is most strain'd with no war;
# Not she knows not how said deep and summer,
# Lest, begs not withouts, for, ambitition, against my
# brois, not much here a careful garment denied togeth,
# And all the seat of limit's own name, ho,
# Our sires, only slight.
#
# SICINIUS:
# Go, in 't;'tis ha!
#
# Citizens:
# Do you the poor hath to send you mock up in your cheeks?
# The prims are on of traitor, now now,
# And after hours are thou slept becomes.
# Tall makes Katches and stine with France shools,
# O, when I will revenue him with the duke:
# Where is he hid show me? have you slander'd him;
# Had he me no sign true, and you, marrying
# Were his neck, foils, blow with woe.
#
# BONARTIO:
# Welcome, let us to
# Torment your honours.
#
# MENENIUS:
# Masters, masters,
# We have seen in haste, which shall heaven your part,
# And have I owe with you.
#
# DUKE OF AUMERLE:
# Stay, art thou, Romeo, that afterword poison
# Many than things to exile; whisper it exceeds
# Like thus slanderous than direct and fair procure,
# So from your father, emperity, you, your worship,
# Even weep in me in my true appoint!
# Thy father best clouds, here 'smock and happy
# To try, and not hear them ashorest, nothing cames
# To bear him as
